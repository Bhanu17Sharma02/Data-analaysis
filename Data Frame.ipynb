# %%
import pandas as pd
import numpy as np

# %%
from numpy.random import randn

# %%
np.random.seed(101) #seed just track or save index of randon variable generated by random module

# %%
df=pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A -1.467514 -0.494095 -0.162535  0.485809
# B  0.392489  0.221491 -0.855196  1.541990
# C  0.666319 -0.538235 -0.568581  1.407338
# D  0.641806 -0.905100 -0.391157  1.028293
# E -1.972605 -0.866885  0.720788 -1.223082

# %%
df.rename(columns={'W':'e'})
# Out:
#           e         X         Y         Z
# A -1.467514 -0.494095 -0.162535  0.485809
# B  0.392489  0.221491 -0.855196  1.541990
# C  0.666319 -0.538235 -0.568581  1.407338
# D  0.641806 -0.905100 -0.391157  1.028293
# E -1.972605 -0.866885  0.720788 -1.223082

# %%
df.rename({'A':1,'B':2},axis='index')
# Out:
#           W         X         Y         Z
# 1 -1.467514 -0.494095 -0.162535  0.485809
# 2  0.392489  0.221491 -0.855196  1.541990
# C  0.666319 -0.538235 -0.568581  1.407338
# D  0.641806 -0.905100 -0.391157  1.028293
# E -1.972605 -0.866885  0.720788 -1.223082

# %% [markdown]
# axis for row=0, axis for column=1

# %%
df.rename({'A':1,'B':0},axis='index') # or df.rename({index={'A':1,'B':2}})
# Out:
#           W         X         Y         Z
# 1 -1.467514 -0.494095 -0.162535  0.485809
# 0  0.392489  0.221491 -0.855196  1.541990
# C  0.666319 -0.538235 -0.568581  1.407338
# D  0.641806 -0.905100 -0.391157  1.028293
# E -1.972605 -0.866885  0.720788 -1.223082

# %%
df
# Out:
#           W         X         Y         Z
# A -1.467514 -0.494095 -0.162535  0.485809
# B  0.392489  0.221491 -0.855196  1.541990
# C  0.666319 -0.538235 -0.568581  1.407338
# D  0.641806 -0.905100 -0.391157  1.028293
# E -1.972605 -0.866885  0.720788 -1.223082

# %%
df.rename({'A':0,'B':2},axis='index')
# Out:
#           W         X         Y         Z
# 0 -1.467514 -0.494095 -0.162535  0.485809
# 2  0.392489  0.221491 -0.855196  1.541990
# C  0.666319 -0.538235 -0.568581  1.407338
# D  0.641806 -0.905100 -0.391157  1.028293
# E -1.972605 -0.866885  0.720788 -1.223082

# %%
df[:]
# Out:
#           W         X         Y         Z
# A -1.467514 -0.494095 -0.162535  0.485809
# B  0.392489  0.221491 -0.855196  1.541990
# C  0.666319 -0.538235 -0.568581  1.407338
# D  0.641806 -0.905100 -0.391157  1.028293
# E -1.972605 -0.866885  0.720788 -1.223082

# %%
df[:2]
# Out:
#           W         X         Y         Z
# A -1.467514 -0.494095 -0.162535  0.485809
# B  0.392489  0.221491 -0.855196  1.541990

# %%
df[['W','X']]
# Out:
#           W         X
# A -1.467514 -0.494095
# B  0.392489  0.221491
# C  0.666319 -0.538235
# D  0.641806 -0.905100
# E -1.972605 -0.866885

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
df.size
# Out:
# 20

# %%
df.shape
# Out:
# (5, 4)

# %%
df
# Out:
#           W         X         Y         Z
# A -1.467514 -0.494095 -0.162535  0.485809
# B  0.392489  0.221491 -0.855196  1.541990
# C  0.666319 -0.538235 -0.568581  1.407338
# D  0.641806 -0.905100 -0.391157  1.028293
# E -1.972605 -0.866885  0.720788 -1.223082

# %%
df['add_new']=df['W']+df['Y']

# %%
df
# Out:
#           W         X         Y         Z   add_new
# A -1.467514 -0.494095 -0.162535  0.485809 -1.630049
# B  0.392489  0.221491 -0.855196  1.541990 -0.462707
# C  0.666319 -0.538235 -0.568581  1.407338  0.097738
# D  0.641806 -0.905100 -0.391157  1.028293  0.250649
# E -1.972605 -0.866885  0.720788 -1.223082 -1.251818

# %%
df.drop('add_new',axis=1) #df.drop(column_name,axis=1#for column)
# Out:
#           W         X         Y         Z
# A -1.467514 -0.494095 -0.162535  0.485809
# B  0.392489  0.221491 -0.855196  1.541990
# C  0.666319 -0.538235 -0.568581  1.407338
# D  0.641806 -0.905100 -0.391157  1.028293
# E -1.972605 -0.866885  0.720788 -1.223082

# %%
df.drop('A') # drop 'A' row or    df.drop('E',axis=0)
# Out:
#           W         X         Y         Z   add_new
# B  0.392489  0.221491 -0.855196  1.541990 -0.462707
# C  0.666319 -0.538235 -0.568581  1.407338  0.097738
# D  0.641806 -0.905100 -0.391157  1.028293  0.250649
# E -1.972605 -0.866885  0.720788 -1.223082 -1.251818

# %%
df
# Out:
#           W         X         Y         Z   add_new
# A -1.467514 -0.494095 -0.162535  0.485809 -1.630049
# B  0.392489  0.221491 -0.855196  1.541990 -0.462707
# C  0.666319 -0.538235 -0.568581  1.407338  0.097738
# D  0.641806 -0.905100 -0.391157  1.028293  0.250649
# E -1.972605 -0.866885  0.720788 -1.223082 -1.251818

# %%
df[:2]
# Out:
#           W         X         Y         Z   add_new
# A -1.467514 -0.494095 -0.162535  0.485809 -1.630049
# B  0.392489  0.221491 -0.855196  1.541990 -0.462707

# %%
df1=pd.DataFrame([
[1,2],[4,5],[7,8]],index=['cobra','viper','sidewinder'],columns=['max_speed','shield'])

# %%
df1
# Out:
#             max_speed  shield
# cobra               1       2
# viper               4       5
# sidewinder          7       8

# %% [markdown]
# loc->pass row label
# iloc-> pass row index

# %%
df1.loc['cobra']
# Out:
# max_speed    1
# shield       2
# Name: cobra, dtype: int64

# %%
df1.iloc[1]
# Out:
# max_speed    4
# shield       5
# Name: viper, dtype: int64

# %%
df1.loc[['cobra','viper']]
# Out:
#        max_speed  shield
# cobra          1       2
# viper          4       5

# %%
df1[:2]
# Out:
#        max_speed  shield
# cobra          1       2
# viper          4       5

# %%
df1.loc["cobra":"sidewinder","max_speed"] #upper bound included
# Out:
# cobra         1
# viper         4
# sidewinder    7
# Name: max_speed, dtype: int64

# %%
df1.iloc[0:1,:1] #upper bound excluded
# Out:
#        max_speed
# cobra          1

# %%
data={'state':['up','up'],
      'year':[2000,2001],
       'pop':[1.2,3.4]}

# %%
frame=pd.DataFrame(data)

# %%
frame
# Out:
#   state  year  pop
# 0    up  2000  1.2
# 1    up  2001  3.4

# %%
frame.index.name="S.no"

# %%
frame
# Out:
#      state  year  pop
# S.no
# 0       up  2000  1.2
# 1       up  2001  3.4
