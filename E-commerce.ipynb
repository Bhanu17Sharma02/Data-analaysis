# %%
import numpy as np
import pandas as pd

# %%
df =pd.read_csv("Ecommerce Purchases")

# %%
df.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# Address             10000 non-null object
# Lot                 10000 non-null object
# AM or PM            10000 non-null object
# Browser Info        10000 non-null object
# Company             10000 non-null object
# Credit Card         10000 non-null int64
# CC Exp Date         10000 non-null object
# CC Security Code    10000 non-null int64
# CC Provider         10000 non-null object
# Email               10000 non-null object
# Job                 10000 non-null object
# IP Address          10000 non-null object
# Language            10000 non-null object
# Purchase Price      10000 non-null float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %% [markdown]
# what is the average  purchase price?

# %%
df['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %%
df['Purchase Price'].min()  #min value
# Out:
# 0.0

# %%
df['Purchase Price'].max() #max value
# Out:
# 99.99

# %%
df[df['Language']=='en'].count()
# Out:
# Address             1098
# Lot                 1098
# AM or PM            1098
# Browser Info        1098
# Company             1098
# Credit Card         1098
# CC Exp Date         1098
# CC Security Code    1098
# CC Provider         1098
# Email               1098
# Job                 1098
# IP Address          1098
# Language            1098
# Purchase Price      1098
# dtype: int64

# %%
df[df['Job']=='Lawyer'].count()
# Out:
# Address             30
# Lot                 30
# AM or PM            30
# Browser Info        30
# Company             30
# Credit Card         30
# CC Exp Date         30
# CC Security Code    30
# CC Provider         30
# Email               30
# Job                 30
# IP Address          30
# Language            30
# Purchase Price      30
# dtype: int64

# %%
df["AM or PM"].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %% [markdown]
# what are the 5 most five common job titles?

# %%
a=df['Job'].value_counts()
a.head()
# Out:
# Interior and spatial designer        31
# Lawyer                               30
# Social researcher                    28
# Research officer, political party    27
# Designer, jewellery                  27
# Name: Job, dtype: int64

# %%
b=df.groupby("Language")

# %%
b.count()
# Out:
#           Address   Lot  AM or PM  Browser Info  Company  Credit Card  \
# Language
# de           1155  1155      1155          1155     1155         1155
# el           1137  1137      1137          1137     1137         1137
# en           1098  1098      1098          1098     1098         1098
# es           1095  1095      1095          1095     1095         1095
# fr           1097  1097      1097          1097     1097         1097
# it           1086  1086      1086          1086     1086         1086
# pt           1118  1118      1118          1118     1118         1118
# ru           1155  1155      1155          1155     1155         1155
# zh           1059  1059      1059          1059     1059         1059
#
#           CC Exp Date  CC Security Code  CC Provider  Email   Job  IP Address  \
# Language
# de               1155              1155         1155   1155  1155        1155
# el               1137              1137         1137   1137  1137        1137
# ...

# %%
b.min()
# Out:
#                                                     Address    Lot AM or PM  \
# Language
# de           000 Martin Shoal Apt. 004\nNew Megan, FM 61399  00 Bh       AM
# el        000 Mills Expressway Apt. 223\nGutierrezview, ...  00 FN       AM
# en        000 Jared Shoals Apt. 244\nRamirezmouth, IL 12450  00 Cd       AM
# es                   001 Mary Course\nWallacestad, AK 93130  00 Aj       AM
# fr        00009 Sharon Forks Apt. 078\nWest Sabrinabury,...  00 AT       AM
# it          00095 Williams Ville\nSheilafurt, MS 10645-1117  00 GM       AM
# pt        00039 John Creek Suite 511\nEast Matthew, VI 3...  00 AG       AM
# ru        00058 Jordan Locks Suite 252\nBradleymouth, IA...  00 Bq       AM
# zh             001 Wilcox Manors\nDavidville, FM 41330-2079  00 CJ       AM
#
#                                                Browser Info  \
# Language
# de        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_0)...
# el        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_0)...
# ...

# %%
type(b)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df[df['Lot']=="90 WT"]['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %%
df[df["Credit Card"]==4926535242672853]['Email']
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %%
c=df[(df["CC Provider"]=="American Express") & (df["Purchase Price"]>=95)]

# %%
c.count()
# Out:
# Address             39
# Lot                 39
# AM or PM            39
# Browser Info        39
# Company             39
# Credit Card         39
# CC Exp Date         39
# CC Security Code    39
# CC Provider         39
# Email               39
# Job                 39
# IP Address          39
# Language            39
# Purchase Price      39
# dtype: int64

# %%
y=0
for e in df["CC Exp Date"]:
      if e[3:]=='25':
            y+=1

# %%
y
# Out:
# 1033

# %%
sum(df["CC Exp Date"].apply(lambda x: x[3:])=='25')
# Out:
# 1033

# %%
l1=list(map(lambda e: e[3:]=='25',df["CC Exp Date"]))

# %%
sum(df["CC Exp Date"].apply(lambda x: x[3:]=='25'))
# Out:
# 1033

# %%
c=df.groupby('Email')['Email']

# %%
d=c.count()
#d.sort_values(ascending = False).head()
d.value_counts().head()
# Out:
# 1    9908
# 2      46
# Name: Email, dtype: int64

# %%
d.sort_values(ascending=False)
# Out:
# Email
# leekathy@yahoo.com               2
# jacob57@hotmail.com              2
# swilliams@yahoo.com              2
# laura48@gmail.com                2
# christopher29@gmail.com          2
#                                 ..
# nmcguire@williams.com            1
# nmccarthy@figueroa-jones.com     1
# nmartinez@gmail.com              1
# nmartin@harrison-murillo.info    1
# aabbott@hotmail.com              1
# Name: Email, Length: 9954, dtype: int64

# %%
d.sort_values(ascending=False).head()
# Out:
# Email
# leekathy@yahoo.com         2
# jacob57@hotmail.com        2
# swilliams@yahoo.com        2
# laura48@gmail.com          2
# christopher29@gmail.com    2
# Name: Email, dtype: int64

# %%
for e in c:
    e=str(e)
    print(e.split('@')[1])
# Out:
# hotmail.com', 4696    aabbott
# maddox-mann.info', 9236    aacosta
# yahoo.com', 2172    aallen
# yahoo.com', 1539    aalvarez
# gmail.com', 3603    aandersen
# hotmail.com', 5503    aaron16
# gmail.com', 5113    aaron49
# gmail.com', 5494    aaron54
# hotmail.com', 7318    aaron77
# gmail.com', 5221    aaronfigueroa
# hotmail.com', 8983    aaronfrancis
# johnson.com', 3354    aaronhart
# higgins.com', 4322    aaronhenson
# hotmail.com', 9799    aaronjones
# hoover.net', 3625    aarontravis
# taylor-anderson.net', 2000    aaronwatson
# diaz-rodgers.net', 1518    abailey
# tanner-thomas.com', 6858    abaker
# yahoo.com', 7722    abarnes
# hotmail.com', 814    abarton
# gmail.com', 8410    abbottmalik
# taylor.com', 5624    abbottpaula
# hotmail.com', 5729    abbottsusan
# luna.org', 1630    aberry
# wells.net', 7139    aberry
# gmail.com', 2336    abigail01
# gmail.com', 9500    abigail26
# evans-logan.com', 7164    abigail46
# jimenez-hansen.org', 9022    abigail73
# ...

# %%
f=df['Email'].apply(lambda x: x.split('@')[1])

# %%
f.value_counts().head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %%
f.sort_values(ascending=False).head()
# Out:
# 7734     zuniga-jackson.com
# 2788    zimmerman-clark.com
# 5264              zhang.com
# 3025              zhang.biz
# 8942             zavala.org
# Name: Email, dtype: object
